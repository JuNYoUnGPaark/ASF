# %% [markdown]
# ### Position plan
# 4가지 고전 HAR set 이외의 데이터셋의 의미: 다른 도메인/시나리오/난이도 하나를 더 제공할 때 의미가 있을 듯. \
# 그러면서도 다른 4개 데이터셋과 비교가 자연스럽게 이어질 수 있게 무조건 많은 feature를 포함하면 안될 듯. \
# Wearable device에 적용이 가능하다는 장점 부각도 중요하지만 현재 Watch들의 데이터 품질은 떨어진다고 판단.
#
#
# 1. Sensor 조합 기준
#     - 가장 흔한 Baseline: Phone-only & acc-only
#     - 조금 더 풍부한 정보 활용: Phone-only & acc+gyro
#
# 2. Device 기준
#     - 전통적: Phone 1대
#     - 요즘 증가 추세: Watch 1대 OR Phone+Watch
#
# - 가장 무난한 조합: Phone & acc+gyro
# - 단, 지금 gyro는 망가진 Stream이 많다. (특히 `gear1`, `gear2`)
#
# ---
# - **방안1: Phone+Gyro & acc+gyro**\
# *"We primarily focus on IMU-based wearable HAR using both smartphone and smartwatch accelerometer+gyroscope signals. However, due to corrupted or extremely short gyroscope recordings in some watch devices (e.g., Gear series), we only use accelerometer channels for those devices after a simple quality-control filtering (minimum sample count & plausible sampling rate).”*
#
# - `phone` → acc+gyro 6채널
# - `lgwatch` → acc+gyro 6채널
# - `gear` → acc 3채널 + gyro 3채널은 0으로 채우기 (또는 마스크) “gyro 없는 디바이스도 있다”는 걸 자연스럽게 배우게 만들 수 있음."
#
# - **방안2: acc+gyro & Phone-only**
#     - 기존 4개와 가장 자연스럽게 이어짐. 모든 데이터셋에서 smartphone IMU( acc+gyro ) 기준으로 비교 가능
#     - 추가/강화가 필요하면 그때 Watch를 쓰자.

# %%
import os
from google.colab import drive

# 1. 드라이브 연결
drive.mount('/content/drive')

# 2. 파일이 있는 폴더로 이동 (이미지의 경로 기준)
os.chdir('/content/drive/MyDrive/Colab Notebooks/ASF/HHAR')

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/Colab Notebooks/ASF/HHAR

# %%
import shutil

drive_path = '/content/drive/MyDrive/Colab Notebooks/HAR_data/HHAR/Activity recognition exp'
local_path = '/content/HHARPhone'
print(f"구글 드라이브({drive_path})에서 로컬({local_path})로 복사 중... (잠시만 기다려주세요)")

if not os.path.exists(local_path):
    shutil.copytree(drive_path, local_path)
    print("복사 완료! 이제 로컬 디스크에서 데이터를 읽습니다. (속도 ↑)")
else:
    print("이미 로컬에 데이터가 있습니다. 복사를 건너뜁니다.")
# Out:
# 구글 드라이브(/content/drive/MyDrive/Colab Notebooks/HAR_data/HHAR/Activity recognition exp)에서 로컬(/content/HHARPhone)로 복사 중... (잠시만 기다려주세요)
# 복사 완료! 이제 로컬 디스크에서 데이터를 읽습니다. (속도 ↑)

# %%
# !pip install fvcore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=03e0fcdf2fa595eecf6583a2c1a015d30b6a09014868613b9a0f073e67d8a75d
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=bc5de4fa50561d6a987d32f2ff06c91ebb679b6e2f34e9d35819fcb64a162498
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# ...

# %%
# !python train.py
# Out:
# 🚀 [Dataset] Loading HHAR data from /content/HHARPhone...
#    - Acc: 13,062,475 rows | Gyro: 13,932,632 rows
# ⚡ [Dataset] Converting timestamps & sorting...
# ⚡ [Dataset] Merging Acc & Gyro (merge_asof)...
#    - Labels: {'bike': 0, 'sit': 1, 'stairsdown': 2, 'stairsup': 3, 'stand': 4, 'walk': 5}
# ⚡ [Dataset] Slicing windows...
# Processing Groups: 100% 18/18 [00:05<00:00,  3.12it/s]
# ✅ [Dataset] Ready! Total Windows: 84,430
# Train samples: 67544, Test samples: 16886
# [01/50] Train Loss: 0.855 | F1: 0.8011  |  Test F1: 0.7860 (Best: 0.7860) Saved Best Model
# [02/50] Train Loss: 0.611 | F1: 0.8903  |  Test F1: 0.8252 (Best: 0.8252) Saved Best Model
# [03/50] Train Loss: 0.562 | F1: 0.9068  |  Test F1: 0.8709 (Best: 0.8709) Saved Best Model
# [04/50] Train Loss: 0.535 | F1: 0.9159  |  Test F1: 0.7662 (Best: 0.8709)
# [05/50] Train Loss: 0.512 | F1: 0.9221  |  Test F1: 0.9156 (Best: 0.9156) Saved Best Model
# ...

# %%
# !python visualize.py
# Out:
# --------------------------------------------------------------------------------
# Running Visualization...
# Loading weights from: /content/drive/MyDrive/Colab Notebooks/ASF/HHAR/HHAR_ASF.pth
# --------------------------------------------------------------------------------
# 🚀 [Dataset] Loading HHAR data from /content/HHARPhone...
#    - Acc: 13,062,475 rows | Gyro: 13,932,632 rows
# ⚡ [Dataset] Converting timestamps & sorting...
# ⚡ [Dataset] Merging Acc & Gyro (merge_asof)...
#    - Labels: {'bike': 0, 'sit': 1, 'stairsdown': 2, 'stairsup': 3, 'stand': 4, 'walk': 5}
# ⚡ [Dataset] Slicing windows...
# Processing Groups: 100% 18/18 [00:05<00:00,  3.27it/s]
# ✅ [Dataset] Ready! Total Windows: 84,430
# Dataset Labels Detected: ['bike', 'sit', 'stairsdown', 'stairsup', 'stand', 'walk']
# ✅ Model weights loaded successfully!
# --------------------------------------------------------------------------------
# Evaluating Model Efficiency...
# 1. Parameters       : 0.0955 M
# ...
