# %%
import os
from google.colab import drive

# 1. 드라이브 연결
drive.mount('/content/drive')

# 2. 파일이 있는 폴더로 이동 (이미지의 경로 기준)
os.chdir('/content/drive/MyDrive/Colab Notebooks/ASF/motion-sense')

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/Colab Notebooks/ASF/motion-sense

# %%
# !pip install fvcore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=64661d665c0f59cc0c570fd0bcc6dec1540c254514a3b22d6660d9391ee105e9
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=978c7f9f2ad9aeb062a0ff498de1eb7f090544908878fb9543374df920a80a0f
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# ...

# %%
# !python train.py
# Out:
# [MotionSenseDataset] windows: 22053, classes: 6
# Classes map: {'dws': 0, 'jog': 1, 'sit': 2, 'std': 3, 'ups': 4, 'wlk': 5}
# Train size: 17642, Test size: 4411
# [01/50] Train Loss: 0.854 | F1: 0.7359  |  Test F1: 0.8576 (Best: 0.8576) Saved Best Model
# [02/50] Train Loss: 0.440 | F1: 0.9445  |  Test F1: 0.8188 (Best: 0.8576)
# [03/50] Train Loss: 0.376 | F1: 0.9662  |  Test F1: 0.7801 (Best: 0.8576)
# [04/50] Train Loss: 0.353 | F1: 0.9751  |  Test F1: 0.9332 (Best: 0.9332) Saved Best Model
# [05/50] Train Loss: 0.327 | F1: 0.9832  |  Test F1: 0.7823 (Best: 0.9332)
# [06/50] Train Loss: 0.322 | F1: 0.9833  |  Test F1: 0.9833 (Best: 0.9833) Saved Best Model
# [07/50] Train Loss: 0.312 | F1: 0.9861  |  Test F1: 0.8182 (Best: 0.9833)
# [08/50] Train Loss: 0.302 | F1: 0.9894  |  Test F1: 0.9000 (Best: 0.9833)
# [09/50] Train Loss: 0.301 | F1: 0.9891  |  Test F1: 0.9562 (Best: 0.9833)
# [10/50] Train Loss: 0.295 | F1: 0.9911  |  Test F1: 0.7054 (Best: 0.9833)
# ...

# %%
# !python visualize.py
# Out:
# --------------------------------------------------------------------------------
# Running Visualization...
# Loading weights from: /content/drive/MyDrive/Colab Notebooks/ASF/motion-sense/motion-sense_ASF.pth
# --------------------------------------------------------------------------------
# [MotionSenseDataset] windows: 22053, classes: 6
# Classes map: {'dws': 0, 'jog': 1, 'sit': 2, 'std': 3, 'ups': 4, 'wlk': 5}
# Total samples: 22053 | Test samples: 4411
# ✅ Model weights loaded successfully!
# --------------------------------------------------------------------------------
# Evaluating Model Efficiency...
# 1. Parameters       : 0.0955 M
# 2. FLOPs / sample   : 6.726 M
# 3. Infer time       : 2.15 ms/sample
# --------------------------------------------------------------------------------
# Extracting features and predictions...
# Generating Confusion Matrix...
#
# ...
# Classification Report
# ...
#               precision    recall  f1-score   support
#
# ...
