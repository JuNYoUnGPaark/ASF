# %%
import os
from google.colab import drive

# 1. 드라이브 연결
drive.mount('/content/drive')

# 2. 파일이 있는 폴더로 이동 (이미지의 경로 기준)
os.chdir('/content/drive/MyDrive/Colab Notebooks/ASF/PAMAP2')

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/Colab Notebooks/ASF/PAMAP2

# %%
# !pip install fvcore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=31bcda4fd9c4fdc3deef47900233856346c14b9bcb3f52712e87aff295442ae6
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=6754b669638be86471b0bd6799435cad685b894f12d0bb577cfdfb7bfdd955dc
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# ...

# %%
# !python train.py
# Out:
# ...
# Loaded PAMAP2 dataset
#   X shape : (30353, 128, 36)  (N, T, C)
#   y shape : (30353,)  (N,)
#   Classes : 12
# ...
# Train samples: 24282, Test samples: 6071
# [01/50] Train Loss: 1.420 | F1: 0.6649  |  Test F1: 0.7536 (Best: 0.7536) Saved Best Model
# [02/50] Train Loss: 0.888 | F1: 0.8553  |  Test F1: 0.8048 (Best: 0.8048) Saved Best Model
# [03/50] Train Loss: 0.775 | F1: 0.8883  |  Test F1: 0.9034 (Best: 0.9034) Saved Best Model
# [04/50] Train Loss: 0.712 | F1: 0.9031  |  Test F1: 0.9006 (Best: 0.9034)
# [05/50] Train Loss: 0.645 | F1: 0.9183  |  Test F1: 0.9168 (Best: 0.9168) Saved Best Model
# [06/50] Train Loss: 0.618 | F1: 0.9238  |  Test F1: 0.9251 (Best: 0.9251) Saved Best Model
# [07/50] Train Loss: 0.599 | F1: 0.9275  |  Test F1: 0.8954 (Best: 0.9251)
# [08/50] Train Loss: 0.566 | F1: 0.9372  |  Test F1: 0.9316 (Best: 0.9316) Saved Best Model
# [09/50] Train Loss: 0.550 | F1: 0.9382  |  Test F1: 0.9347 (Best: 0.9347) Saved Best Model
# ...

# %%
# !python visualize.py
# Out:
# --------------------------------------------------------------------------------
# Running Visualization...
# Loading weights from: /content/drive/MyDrive/Colab Notebooks/ASF/PAMAP2/PAMAP2_ASF.pth
# --------------------------------------------------------------------------------
# ...
# Loaded PAMAP2 dataset
#   X shape : (30353, 128, 36)  (N, T, C)
#   y shape : (30353,)  (N,)
#   Classes : 12
# ...
# ✅ Model weights loaded successfully!
# --------------------------------------------------------------------------------
# Evaluating Model Efficiency...
# 1. Parameters       : 0.1010 M
# 2. FLOPs / sample   : 7.341 M
# 3. Infer time       : 1.52 ms/sample
# --------------------------------------------------------------------------------
# Extracting features and predictions...
# Generating Confusion Matrix...
#
# ...
# Classification Report
# ...
#                    precision    recall  f1-score   support
#
#             Lying     0.9916    0.9932    0.9924       592
# ...
