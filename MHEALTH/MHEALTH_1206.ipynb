# %%
import os
from google.colab import drive

# 1. 드라이브 연결
drive.mount('/content/drive')

# 2. 파일이 있는 폴더로 이동 (이미지의 경로 기준)
os.chdir('/content/drive/MyDrive/Colab Notebooks/ASF/MHEALTH')

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/Colab Notebooks/ASF/MHEALTH

# %%
# !pip install fvcore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=2014d2931dc28426780fc92e073e694694f094a42a64746e23eefeec93deb666
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=f681fb01df4cb7a3c6387fde97f60c5fb0d425ff6b8e75a4fb1518c1b91b9567
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# ...

# %%
# !python train.py
# Out:
# Found 10 log files in /content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET
# ...
# Loaded MHEALTH dataset
#   X shape : (5361, 128, 23)  (N, T, C)
#   y shape : (5361,)  (N,)
# ...
# Train samples: 4288, Test samples: 1073
# [01/50] Train Loss: 2.312 | F1: 0.2472  |  Test F1: 0.3742 (Best: 0.3742) Saved Best Model
# [02/50] Train Loss: 1.460 | F1: 0.5618  |  Test F1: 0.6607 (Best: 0.6607) Saved Best Model
# [03/50] Train Loss: 1.094 | F1: 0.7178  |  Test F1: 0.7334 (Best: 0.7334) Saved Best Model
# [04/50] Train Loss: 0.948 | F1: 0.7875  |  Test F1: 0.8722 (Best: 0.8722) Saved Best Model
# [05/50] Train Loss: 0.787 | F1: 0.8775  |  Test F1: 0.9525 (Best: 0.9525) Saved Best Model
# [06/50] Train Loss: 0.675 | F1: 0.9295  |  Test F1: 0.9611 (Best: 0.9611) Saved Best Model
# [07/50] Train Loss: 0.640 | F1: 0.9323  |  Test F1: 0.9225 (Best: 0.9611)
# [08/50] Train Loss: 0.559 | F1: 0.9562  |  Test F1: 0.9674 (Best: 0.9674) Saved Best Model
# ...

# %%
# !python visualize.py
# Out:
# --------------------------------------------------------------------------------
# Running Visualization...
# Loading weights from: /content/drive/MyDrive/Colab Notebooks/ASF/MHEALTH/MHEALTH_ASF.pth
# --------------------------------------------------------------------------------
# Found 10 log files in /content/drive/MyDrive/Colab Notebooks/HAR_data/MHEALTHDATASET
# ...
# Loaded MHEALTH dataset
#   X shape : (5361, 128, 23)  (N, T, C)
#   y shape : (5361,)  (N,)
# ...
# ✅ Model weights loaded successfully!
# --------------------------------------------------------------------------------
# Evaluating Model Efficiency...
# 1. Parameters       : 0.0990 M
# 2. FLOPs / sample   : 7.074 M
# 3. Infer time       : 1.96 ms/sample
# --------------------------------------------------------------------------------
# Extracting features and predictions...
# Generating Confusion Matrix...
#
# ...
# Classification Report
# ...
#               precision    recall  f1-score   support
#
# ...
