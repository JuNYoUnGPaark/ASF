# %%
import os
from google.colab import drive

# 1. 드라이브 연결
drive.mount('/content/drive')

# 2. 파일이 있는 폴더로 이동 (이미지의 경로 기준)
os.chdir('/content/drive/MyDrive/Colab Notebooks/ASF/WISDM')

print(f"현재 위치: {os.getcwd()}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 현재 위치: /content/drive/MyDrive/Colab Notebooks/ASF/WISDM

# %%
# !pip install fvcore
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=b6e4987c2f0b6e92881376fb23fd8255d9c9677a9a0a139dce803486778601f8
#   Stored in directory: /root/.cache/pip/wheels/ed/9f/a5/e4f5b27454ccd4596bd8b62432c7d6b1ca9fa22aef9d70a16a
# ...
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=38e2aacfcff9dab41ddb0e40d3882462508865e360e4a91c97e8ef9d89f5c975
#   Stored in directory: /root/.cache/pip/wheels/7c/96/04/4f5f31ff812f684f69f40cb1634357812220aac58d4698048c
# Successfully built fvcore iopath
# ...

# %%
# !python train.py
# Out:
# Loading WISDM file: /content/drive/MyDrive/Colab Notebooks/HAR_data/WISDM_ar_v1.1_raw.txt ...
# ...
# Loaded WISDM dataset (Synced Logic)
#   X shape       : (27108, 80, 3)  (N, T, C)
#   y shape       : (27108,)  (N,)
#   subjects      : 36 subjects
#   Class Map     : {'Walking': 0, 'Jogging': 1, 'Sitting': 2, 'Standing': 3, 'Upstairs': 4, 'Downstairs': 5}
# ...
# Train samples: 21686, Test samples: 5422
# [01/50] Train Loss: 0.884 | F1: 0.6102  |  Test F1: 0.2595 (Best: 0.2595) Saved Best Model
# [02/50] Train Loss: 0.607 | F1: 0.7638  |  Test F1: 0.8652 (Best: 0.8652) Saved Best Model
# [03/50] Train Loss: 0.487 | F1: 0.9039  |  Test F1: 0.5860 (Best: 0.8652)
# [04/50] Train Loss: 0.452 | F1: 0.9237  |  Test F1: 0.5150 (Best: 0.8652)
# [05/50] Train Loss: 0.422 | F1: 0.9380  |  Test F1: 0.9186 (Best: 0.9186) Saved Best Model
# [06/50] Train Loss: 0.406 | F1: 0.9462  |  Test F1: 0.9472 (Best: 0.9472) Saved Best Model
# [07/50] Train Loss: 0.392 | F1: 0.9526  |  Test F1: 0.9319 (Best: 0.9472)
# ...

# %%
# !python visualize.py
# Out:
# --------------------------------------------------------------------------------
# Running Visualization...
# Loading weights from: /content/drive/MyDrive/Colab Notebooks/ASF/WISDM/WISDM_ASF.pth
# --------------------------------------------------------------------------------
# Loading WISDM file: /content/drive/MyDrive/Colab Notebooks/HAR_data/WISDM_ar_v1.1_raw.txt ...
# ...
# Loaded WISDM dataset (Synced Logic)
#   X shape       : (27108, 80, 3)  (N, T, C)
#   y shape       : (27108,)  (N,)
#   subjects      : 36 subjects
#   Class Map     : {'Walking': 0, 'Jogging': 1, 'Sitting': 2, 'Standing': 3, 'Upstairs': 4, 'Downstairs': 5}
# ...
# ✅ Model weights loaded successfully!
# --------------------------------------------------------------------------------
# Evaluating Model Efficiency...
# 1. Parameters       : 0.0950 M
# 2. FLOPs / sample   : 4.156 M
# 3. Infer time       : 1.55 ms/sample
# --------------------------------------------------------------------------------
# ...
